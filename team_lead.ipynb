# %% [markdown]
# # Team Lead Questions

# %% [markdown]
# - сотрудник в первый раз нарушил сроки по задаче и сказал об этом только в последний момент? как будешь поступать в этой ситуации? Если задача очень важная и сроки работы нарушены?
# - Как будешь мотивировать очень умного и ключевого сотрудника в команде, если он попросил повышение в зп , но у компании сейчас нет таких ресурсов сейчас нет (согласование бюджетов, и тд )

# %% [markdown]
# ## Вопросы по лидерству и управлению командой

# %% [markdown]
#     1. **У тебя есть джун+, который работает год без особых успехов в реализации задач и развитии как специалиста, ты проговорил с ним объяснил требования о том что тебя не устраивает его работа, прошел месяц ничего не поменялось.**
#
#     **Что будешь делать с таким сотрудником?**

# %% [markdown]
# Очень хороший управленческий кейс — он проверяет, как ты как тимлид совмещаешь **человечность и эффективность**.
# Вот как бы я действовал по шагам 👇
#
# ---
#
#  🧭 1. Анализ перед решением
#
# Сначала я убеждаюсь, что **проблема действительно в сотруднике**, а не в окружении:
#
# * Проверяю, **было ли у него чёткое понимание целей и критериев успеха** (SMART-цели, measurable KPI).
# * Смотрю, **какие задачи ему давались** — возможно, они были либо слишком сложны, либо слишком разрозненны.
# * Уточняю у менторов / коллег — нет ли проблем в коммуникации или поддержке.
#
# Если после этого очевидно, что дело именно в его **мотивации и профессиональном росте**, двигаюсь дальше.
#
# ---
#
#  🗣️ 2. Прямая и честная обратная связь
#
# * Провожу **вторую, структурированную one-to-one встречу**.
#
#   * Повторно объясняю, какие **ожидания не выполнены** (с конкретикой: примеры задач, дедлайнов, качества кода).
#   * Даю **финальный план улучшения (Performance Improvement Plan)** на 1–2 месяца:
#
#     * конкретные измеримые цели (например: “в течение 4 недель завершить 2 фичи без менторской помощи”, “снизить количество багов в PR до 10%”);
#     * договорённость о **еженедельных чекпоинтах**;
#     * понимание, что **неулучшение = расставание**.
#
# Важно: я не угрожаю, а **объясняю логику и последствия** — чтобы не демотивировать, а стимулировать к действию.
#
# ---
#
#  🧩 3. Поддержка и коучинг
#
# * Даю конкретную **структуру развития**:
#
#   * рекомендую темы для апгрейда (например, тестирование, CI/CD, паттерны);
#   * назначаю **ментора** или парное программирование (если есть опытный коллега);
#   * даю **простые, но значимые задачи**, где он может показать прогресс.
# * Если замечаю улучшения — **публично отмечаю** успех, чтобы усилить мотивацию.
#
# ---
#
#  ⏰ 4. Если прогресса нет
#
# * После согласованного срока провожу **оценку результатов**:
#
#   * если динамики нет — **прямо говорю, что мы вынуждены расстаться**, так как текущий уровень не соответствует требованиям команды.
#   * при этом стараюсь **корректно завершить отношения** — обсуждаю, куда он может двигаться дальше, что ему стоит подтянуть, даю конструктивный фидбэк (exit-интервью).
#
# Главное — не затягивать:
#
# > “Если человек не растёт и не приносит ценности команде, ты как тимлид обязан принять решение, иначе страдает весь коллектив.”
#
# ---
#
#  🧠 5. Для себя — анализ уроков
#
# * Проверяю, **на каком этапе можно было отреагировать раньше**:
#
#   * были ли понятные критерии оценки;
#   * была ли у человека поддержка или менторинг;
#   * не допустил ли я «размытого фидбэка».
#
# ---
#
#  💬 Короткий итог:
#
# > Сначала я даю человеку шанс, создаю прозрачный план роста и поддержку.
# > Если через месяц–два нет изменений — принимаю решение о расставании, чтобы не держать “балласт” и сохранить эффективность команды.
# > Всё делаю максимально корректно и с уважением — так, чтобы человек ушёл с пониманием, а команда видела справедливость.
#
# ---
#
# Хочешь, я помогу оформить этот ответ в виде краткой устной версии на 1 минуту — как для интервью (чтобы звучало естественно и убедительно)?

# %% [markdown]
#     **2. Ты тим лид в команде, у вас две недели до релиза продукта, но ты понимаешь, чтобы сделать эту работу за две недели тебе нужно 2 раза больше человеко-часов   (т.е. сейчас у тебя есть 3 сотрудника, а чтобы сделать эту работу за две недели тебе нужно 6 человек), при этом уже есть обещания перед бизнесом, что через 2 недели этот продукт будет готов , но при этом точно понимаешь, что не получается добиться нужных метрик**
#
#     **Что ты будешь делать в этом случае? Какой твой план действий, чтобы разрешить ситуацию?**

# %% [markdown]
# Это классическая ситуация **time–scope–resources trade-off**, и как тимлиду здесь важно действовать одновременно стратегически и прозрачно.
# Я бы выстроил план действий так:
#
# ---
#
#  🧭 1. Сначала — объективная оценка ситуации
#
# * Провожу **быструю ревизию задач**: что реально критично для релиза (MVP), а что — nice-to-have.
# * Оцениваю **трудозатраты по каждому модулю/фиче**, чтобы иметь точные данные, а не ощущения.
# * Понимаю, **где узкие места**: может, не хватает не просто людей, а конкретных компетенций (например, DevOps или QA).
#
# ---
#
#  🗣️ 2. Коммуникация с бизнесом
#
# * Провожу **открытый разговор с продуктом/бизнес-стейкхолдерами**:
#
#   * объясняю текущее положение, показываю объективные данные (burn-down chart, velocity, оставшиеся story points);
#   * обозначаю три сценария:
#
#     1. 📆 **Сохранить дедлайн, но сократить функционал** (сделать MVP и потом итеративно доработать);
#     2. 👥 **Увеличить ресурсы** (привлечь временно ещё 2–3 разработчиков, например, из соседней команды или подрядчиков);
#     3. ⏰ **Сохранить функционал, но сдвинуть срок** (допустим, +1 неделя на стабилизацию).
#
#   Обычно бизнес выбирает между 1 и 2, если аргументы прозрачны.
#
# ---
#
#  ⚙️ 3. Внутренние меры по оптимизации
#
# * Провожу **приоритизацию по модели MoSCoW** (Must / Should / Could / Won’t).
# * Разбиваю задачи на минимально возможные deliverables, чтобы **релизить итеративно** — пусть даже частично.
# * Организую **ежедневные синки и контроль фокуса** — исключаю «распыление» команды.
# * Если возможно, **временно беру на себя часть задач** (код-ревью, интеграция, DevOps), чтобы разгрузить команду.
# * Проверяю, нет ли **узких мест в CI/CD**, автоматизирую сборку и тестирование — чтобы не терять часы на ручные действия.
#
# ---
#
#  🚨 4. Работа с командой
#
# * Провожу честный разговор: объясняю ситуацию, при этом **не нагружаю паникой**.
# * Мы договариваемся о **режиме фокусной работы**, но без выгорания.
# * Поощряю инициативу: кто может предложить оптимизацию, рефакторинг, ускорение.
# * Поддерживаю морально и защищаю от «лишнего шума» со стороны бизнеса.
#
# ---
#
# 🧩 5. Параллельно — контроль качества и рисков
#
# * Добавляю **QA-инженера раньше**, чем обычно (если нет — использую автотесты).
# * Пишу **чек-листы регрессии** — чтобы не терять время на непредсказуемые баги.
# * Еженедельно показываю **демо бизнесу**, чтобы не было сюрпризов в конце спринта.
#
# ---
#
#  📊 6. Итог
#
# Цель — **сохранить доверие бизнеса и команды**, показать управляемость.
# Если всё сделано грамотно:
#
# * либо мы выпускаем MVP вовремя (пусть урезанный, но стабильный),
# * либо аргументированно получаем отсрочку / поддержку ресурсами.
#
# ---
#
# 💬 **Ключевая идея**:
#
# > Тимлид — это не тот, кто делает невозможное «любой ценой», а тот, кто управляет ожиданиями и делает невозможное *возможно* за счёт прозрачности, приоритизации и коммуникации.
#
# ---

# %% [markdown]
# 3. Как качественно (то есть по каким метрикам) оценивать ML проекты перед бизнесом? Какие бизнес-метрики нужно считать для стейкхолдеров?

# %% [markdown]
# 4. Как правильно строить бэклог работы сотрудника, учитывая тот факт, что ML-исследования сильно не стационарны ?

# %% [markdown]
# 5. Какие у тебя были задачи как у Team Lead?

# %% [markdown]
# 6. Как будешь решать проблему того, что, например, кто-то из твоей команды имеет плохие софт скиллы, и например , ругается с продакт-менеджером на этапе согласования задач и плана работ. Как ты будешь решать этот конфликт?

# %% [markdown]
# 7. Как ты борешься с конфликтами в команде? Как решал конфликты если они были в команде? Были ли эти конфликты в команде?

# %% [markdown]
# 8. Как выстраиваешь систему мотивации для сотрудников? Как выстраиваешь дорожную карту развития сотрудников?

# %% [markdown]
# 9. Как у тебя в команде выстроены процессы? По какой методике работаешь?

# %% [markdown]
# 10. Как оцениваешь производительность сотрудников и ставишь цели (OKR/KPI)?

# %% [markdown]
# 11. Опиши ситуацию, когда команда не успевала по дедлайну — что делал?

# %% [markdown]
# 12. Как организуешь процесс код-ревью и стандарты качества в команде?

# %% [markdown]
# 13. Как принимаешь трудные приоритезационные решения (например, скорость vs качество модели)?

# %% [markdown]
# ## Продукт, бизнес и коммуникация со стейкхолдерами

# %% [markdown]
# 1. Как измеряешь бизнес-эффект от ML-фичи (lift, ROI)?

# %% [markdown]
# 2. Как измеряешь бизнес-эффект от внедрения LLM-решения?

# %% [markdown]
# 3. Как объясняешь нетехническим стейкхолдерам риски и неопределённость моделей?

# %% [markdown]
# 4. Приведи пример, когда ML-решение не оправдало себя — как реагировал?

# %% [markdown]
# 5. Как взаимодействуешь с PM/BA/Dev для выстраивания требований под ML?

# %% [markdown]
# ## Поведенческие / ситуационные вопросы

# %% [markdown]
# ### Принятие решений и ответственность

# %% [markdown]
# 1. Расскажи о ситуации, когда тебе пришлось принять непопулярное решение.
#
# 2. Приведи пример, когда ты настоял на техническом решении, несмотря на давление со стороны менеджмента.
#
# 3. Был ли случай, когда ты принял неправильное решение — как ты понял это и что сделал дальше?
#
# 4. Как ты принимаешь решения, когда нет достаточных данных?
#
# 5. Опиши случай, когда ты отказался от ML-решения и выбрал более простое правило/алгоритм.
#
# 6. Как ты реагируешь, если стейкхолдер хочет запустить модель, не прошедшую полное тестирование?

# %% [markdown]
# ###  Работа с неопределённостью и рисками

# %% [markdown]
# 7. Как справляешься с ситуацией, когда требования меняются во время проекта?
#
# 8. Что ты делаешь, если бизнес не может чётко сформулировать задачу?
#
# 9. Как оцениваешь и доносишь риски проекта, когда есть высокая вероятность провала?
#
# 10. Приведи пример, когда ты минимизировал риск деградации модели в продакшене.
#
# 11. Как действуешь, если нет достаточных данных для обучения модели?
#
# 12. Что делаешь, если после релиза модель показывает нестабильные результаты?

# %% [markdown]
# 1. Как ведёшься с «токсичным» высокопроизводительным инженером?

# %% [markdown]
# 2. Опиши ситуацию, где ты допустил ошибку как лидер — что сделал дальше?

# %% [markdown]
# 3. Как справляешься со стрессом и дедлайнами на уровне команды?

# %% [markdown]
# 4. Расскажи про трудный технический выбор, который ты принял, и его последствия?

# %% [markdown]
# 5. Опиши ситуацию, где ты допустил ошибку как лидер — что сделал дальше?

# %% [markdown]
# 6. Как ты реагируешь, если стейкхолдер хочет запустить модель, не прошедшую полное тестирование?

# %% [markdown]
# 7. Как справляешься с ситуацией, когда требования меняются во время проекта?

# %% [markdown]
# 8. Что ты делаешь, если бизнес не может чётко сформулировать задачу?

# %% [markdown]
# 9. Что делаешь, если после релиза модель показывает нестабильные результаты?

# %%
{
    "parsed": {
        "category": "Other/Unknown",
        "confidence": 0.5,
        "risk_level": "allowed",
        "reasoning": "The website appears to be a betting platform, which is an allowed business type. The text 'ACCESS RESTRICTED' and 'The project is not available for your country for legal reasons' suggests that the site is likely a gambling or betting site, which is allowed under the provided categories. There are no explicit visual indicators of prohibited content such as adult material, drugs, or weapons. The design and text are generic and do not suggest any high-risk activities.",
        "visual_indicators": ["ACCESS RESTRICTED", "The project is not available for your country for legal reasons"],
        "compliance_flags": [],
    },
    "response_text": '```json\n{\n    "category": "Other/Unknown",\n    "confidence": 0.5,\n    "risk_level": "allowed",\n    "reasoning": "The website appears to be a betting platform, which is an allowed business type. The text \'ACCESS RESTRICTED\' and \'The project is not available for your country for legal reasons\' suggests that the site is likely a gambling or betting site, which is allowed under the provided categories. There are no explicit visual indicators of prohibited content such as adult material, drugs, or weapons. The design and text are generic and do not suggest any high-risk activities.",\n    "visual_indicators": ["ACCESS RESTRICTED", "The project is not available for your country for legal reasons"],\n    "compliance_flags": []\n}\n```',
    "inference_time": 16.837538957595825,
}

# %%
## !!!!! Ошибка !!!!!

{
    "parsed": None,
    "response_text": '```json\n{\n    "category": "Other/Unknown",\n    "confidence": 0.5,\n    "risk_level": "allowed",\n    "reasoning": "The website appears to be a sports-related platform, possibly a betting or gaming site, as indicated by the \'SPORTAZA\' logo and the message \'ACCESS RESTRICTED\' which suggests it is a project or service that is not available in certain countries. There are no explicit visual indicators of adult content, substances, weapons, gambling, or other prohibited business types. The design is generic and does not provide strong visual evidence of any prohibited activities.",\n    "visual_indicators": ["SPORTAZA" logo, "ACCESS RESTRICTED" message, generic stadium-like background],\n    "compliance_flags": ["No clear indication of prohibited business types"]\n}\n```',
    "inference_time": 17.976571798324585,
}
